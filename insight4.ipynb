# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
salesdetails=pd.read_csv(r"C:\Users\91858\Downloads\Data Fiesta 2.0 Round 2 Docket\Data Fiesta 2.0 Round 2 Docket\Data Fiesta 2.0 Round 2 Docket\Data Fiesta 2.0 Round 2 -  Data\SALESDETAILS.csv")
region=pd.read_csv(r"C:\Users\91858\Downloads\Data Fiesta 2.0 Round 2 Docket\Data Fiesta 2.0 Round 2 Docket\Data Fiesta 2.0 Round 2 Docket\Data Fiesta 2.0 Round 2 -  Data\REGION.csv")
customer=pd.read_csv(r"C:\Users\91858\Downloads\Data Fiesta 2.0 Round 2 Docket\Data Fiesta 2.0 Round 2 Docket\Data Fiesta 2.0 Round 2 Docket\Data Fiesta 2.0 Round 2 -  Data\CUSTOMERS.csv")
# Out:
# C:\Users\91858\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
region.columns
# Out:
# Index(['Region Name', 'Region Code'], dtype='object')

# %%
df_merge1=pd.merge(salesdetails, customer, on='Address Number')

# %%
df_merge1.head()
# Out:
#    Actual Delivery Date  Address Number   CustKey  Backlog Amount  \
# 0                   NaN        10025919  10025919             NaN
# 1                   NaN        10025919  10025919             NaN
# 2                   NaN        10025919  10025919             NaN
# 3                   NaN        10025919  10025919             NaN
# 4                   NaN        10025919  10025919             NaN
#
#    BackOrder Amount    DateKey  Discount Amount Doc Type Family Class  \
# 0               NaN  7/21/2008              NaN                   T21
# 1               NaN  6/27/2008              NaN                   T21
# 2               NaN   5/8/2008              NaN                   T21
# 3               NaN   5/8/2008              NaN                   T21
# 4               NaN  6/27/2008              NaN                   T21
#
#   Invoice Date  ...  Business Unit  Customer Customer Number Customer Type  \
# 0          NaN  ...              1  Vanstars        10025919            G2
# 1          NaN  ...              1  Vanstars        10025919            G2
# 2          NaN  ...              1  Vanstars        10025919            G2
# 3          NaN  ...              1  Vanstars        10025919            G2
# 4          NaN  ...              1  Vanstars        10025919            G2
#
#   Division  Line of Business         Phone  Region Code  Regional Sales Mgr  \
# 0        2                M1  816-455-8733            1                 S16
# 1        2                M1  816-455-8733            1                 S16
# 2        2                M1  816-455-8733            1                 S16
# 3        2                M1  816-455-8733            1                 S16
# 4        2                M1  816-455-8733            1                 S16
#
#    Search Type
# 0            C
# 1            C
# 2            C
# 3            C
# 4            C
#
# [5 rows x 43 columns]

# %%
df_merge2=pd.merge(df_merge1, region, on='Region Code')

# %%
df_merge2.head()
# Out:
#    Actual Delivery Date  Address Number   CustKey  Backlog Amount  \
# 0                   NaN        10025919  10025919             NaN
# 1                   NaN        10025919  10025919             NaN
# 2                   NaN        10025919  10025919             NaN
# 3                   NaN        10025919  10025919             NaN
# 4                   NaN        10025919  10025919             NaN
#
#    BackOrder Amount    DateKey  Discount Amount Doc Type Family Class  \
# 0               NaN  7/21/2008              NaN                   T21
# 1               NaN  6/27/2008              NaN                   T21
# 2               NaN   5/8/2008              NaN                   T21
# 3               NaN   5/8/2008              NaN                   T21
# 4               NaN  6/27/2008              NaN                   T21
#
#   Invoice Date  ...  Customer Customer Number Customer Type Division  \
# 0          NaN  ...  Vanstars        10025919            G2        2
# 1          NaN  ...  Vanstars        10025919            G2        2
# 2          NaN  ...  Vanstars        10025919            G2        2
# 3          NaN  ...  Vanstars        10025919            G2        2
# 4          NaN  ...  Vanstars        10025919            G2        2
#
#   Line of Business         Phone Region Code  Regional Sales Mgr  Search Type  \
# 0               M1  816-455-8733           1                 S16            C
# 1               M1  816-455-8733           1                 S16            C
# 2               M1  816-455-8733           1                 S16            C
# 3               M1  816-455-8733           1                 S16            C
# 4               M1  816-455-8733           1                 S16            C
#
#    Region Name
# 0      Western
# 1      Western
# 2      Western
# 3      Western
# 4      Western
#
# [5 rows x 44 columns]

# %%
df_merge2.dropna(subset=['Sales Margin Amount'])
# Out:
#         Actual Delivery Date  Address Number   CustKey  Backlog Amount  \
# 425                  39569.0        10025919  10025919             NaN
# 426                  39576.0        10025919  10025919             NaN
# 427                  39597.0        10025919  10025919             NaN
# 428                  39597.0        10025919  10025919             NaN
# 429                  39500.0        10025919  10025919             NaN
# ...                      ...             ...       ...             ...
# 298156               40107.0        10017307  10017307             NaN
# 298157               40170.0        10017307  10017307             NaN
# 298158               39681.0        10017307  10017307             NaN
# 298159               39499.0        10017307  10017307             NaN
# 298160               39681.0        10017307  10017307             NaN
#
#         BackOrder Amount     DateKey  Discount Amount Doc Type Family Class  \
# 425                  NaN    5/1/2008             0.00       RI          T01
# 426                  NaN    5/8/2008             0.00       RI          T01
# 427                  NaN   5/29/2008             0.00       RI
# 428                  NaN   5/29/2008             0.00       RI
# 429                  NaN   2/22/2008           486.32       RI          T10
# ...                  ...         ...              ...      ...          ...
# 298156               NaN  10/21/2009          9709.97       RI          T22
# 298157               NaN  12/23/2009          9709.97       RI          T22
# 298158               NaN   8/21/2008          -192.51       RI
# 298159               NaN   2/21/2008           439.01       RI
# 298160               NaN   8/21/2008           439.01       RI
#
#        Invoice Date  ...     Customer Customer Number Customer Type Division  \
# 425        5/1/2008  ...     Vanstars        10025919            G2        2
# 426        5/8/2008  ...     Vanstars        10025919            G2        2
# 427       5/29/2008  ...     Vanstars        10025919            G2        2
# 428       5/29/2008  ...     Vanstars        10025919            G2        2
# 429       2/22/2008  ...     Vanstars        10025919            G2        2
# ...             ...  ...          ...             ...           ...      ...
# 298156   10/21/2009  ...  Idyll Store        10017307            G3        1
# 298157   12/23/2009  ...  Idyll Store        10017307            G3        1
# 298158    8/21/2008  ...  Idyll Store        10017307            G3        1
# 298159    2/21/2008  ...  Idyll Store        10017307            G3        1
# 298160    8/21/2008  ...  Idyll Store        10017307            G3        1
#
#        Line of Business         Phone Region Code  Regional Sales Mgr  \
# 425                  M1  816-455-8733           1                 S16
# 426                  M1  816-455-8733           1                 S16
# 427                  M1  816-455-8733           1                 S16
# 428                  M1  816-455-8733           1                 S16
# 429                  M1  816-455-8733           1                 S16
# ...                 ...           ...         ...                 ...
# 298156                   816-455-8733           0                  S8
# 298157                   816-455-8733           0                  S8
# 298158                   816-455-8733           0                  S8
# 298159                   816-455-8733           0                  S8
# 298160                   816-455-8733           0                  S8
#
#         Search Type  Region Name
# 425               C      Western
# 426               C      Western
# 427               C      Western
# 428               C      Western
# 429               C      Western
# ...             ...          ...
# 298156            C       Canada
# 298157            C       Canada
# 298158            C       Canada
# 298159            C       Canada
# 298160            C       Canada
#
# [288109 rows x 44 columns]

# %%
indexNames = df_merge2[ df_merge2['Sales Margin Amount'] <0].index
df_merge2.drop(indexNames , inplace=True)

# %%
grouped_df = df_merge2.groupby(['Region Code']).mean()

# %%
df_final=grouped_df.filter(['Region Code','Sales Margin Amount'], axis=1)

# %%
df_final
# Out:
#              Sales Margin Amount
# Region Code
# 0                     280.879130
# 1                     259.269735
# 2                     281.184431
# 3                     205.898786
# 4                     644.159542
# 5                     601.810136

# %%
df_final.sort_values('Sales Margin Amount',ascending=False, inplace=True)

# %%
df_final.to_csv('marginByR.csv')
